# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns
from sklearn.preprocessing import MinMaxScaler

# %%
df=pd.read_csv('data.csv')
df
# Out:
#                         country country_code date_added has_expired  \
# 0      United States of America           US        NaN          No
# 1      United States of America           US        NaN          No
# 2      United States of America           US        NaN          No
# 3      United States of America           US        NaN          No
# 4      United States of America           US        NaN          No
# ...                         ...          ...        ...         ...
# 21995  United States of America           US        NaN          No
# 21996  United States of America           US        NaN          No
# 21997  United States of America           US        NaN          No
# 21998  United States of America           US        NaN          No
# 21999  United States of America           US        NaN          No
#
#               job_board                                    job_description  \
# ...

# %%
df.head()
# Out:
#                     country country_code date_added has_expired  \
# 0  United States of America           US        NaN          No
# 1  United States of America           US        NaN          No
# 2  United States of America           US        NaN          No
# 3  United States of America           US        NaN          No
# 4  United States of America           US        NaN          No
#
#           job_board                                    job_description  \
# 0  jobs.monster.com  TeamSoft is seeing an IT Support Specialist to...
# 1  jobs.monster.com  The Wisconsin State Journal is seeking a flexi...
# 2  jobs.monster.com  Report this job About the Job DePuy Synthes Co...
# 3  jobs.monster.com  Why Join Altec? If you’re considering a career...
# 4  jobs.monster.com  Position ID#  76162 # Positions  1 State  CT C...
#
#                                            job_title             job_type  \
# 0               IT Support Technician Job in Madison   Full Time Employee
# ...

# %%
df.isnull().sum()
# Out:
# country                0
# country_code           0
# date_added         21878
# has_expired            0
# job_board              0
# job_description        0
# job_title              0
# job_type            1628
# location               0
# organization        6867
# page_url               0
# salary             18554
# sector              5194
# uniq_id                0
# dtype: int64

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 22000 entries, 0 to 21999
# Data columns (total 14 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   country          22000 non-null  object
#  1   country_code     22000 non-null  object
#  2   date_added       122 non-null    object
#  3   has_expired      22000 non-null  object
#  4   job_board        22000 non-null  object
#  5   job_description  22000 non-null  object
#  6   job_title        22000 non-null  object
#  7   job_type         20372 non-null  object
#  8   location         22000 non-null  object
#  9   organization     15133 non-null  object
#  10  page_url         22000 non-null  object
#  11  salary           3446 non-null   object
#  12  sector           16806 non-null  object
#  13  uniq_id          22000 non-null  object
# dtypes: object(14)
# memory usage: 2.3+ MB

# %%
to_drop = ['country','country_code','job_board','has_expired','page_url','uniq_id']
df.drop(to_drop, axis=1, inplace = True)

# %%
df.head()
# Out:
#   date_added                                    job_description  \
# 0        NaN  TeamSoft is seeing an IT Support Specialist to...
# 1        NaN  The Wisconsin State Journal is seeking a flexi...
# 2        NaN  Report this job About the Job DePuy Synthes Co...
# 3        NaN  Why Join Altec? If you’re considering a career...
# 4        NaN  Position ID#  76162 # Positions  1 State  CT C...
#
#                                            job_title             job_type  \
# 0               IT Support Technician Job in Madison   Full Time Employee
# 1            Business Reporter/Editor Job in Madison            Full Time
# 2  Johnson & Johnson Family of Companies Job Appl...  Full Time, Employee
# 3                    Engineer - Quality Job in Dixon            Full Time
# 4       Shift Supervisor - Part-Time Job in Camphill   Full Time Employee
#
#                                             location  \
# 0                                  Madison, WI 53702
# ...

# %%
df.describe()
# Out:
#        date_added                                    job_description  \
# count         122                                              22000
# unique         78                                              18744
# top     9/22/2016  12N Horizontal Construction Engineers Job Desc...
# freq            6                                                104
#
#        job_title   job_type    location         organization  \
# count      22000      20372       22000                15133
# unique     18759         39        8423                  738
# top      Monster  Full Time  Dallas, TX  Healthcare Services
# freq         318       6757         646                 1919
#
#                                 salary                     sector
# count                             3446                      16806
# unique                            1737                        163
# top     40,000.00 - 100,000.00 $ /year  Experienced (Non-Manager)
# ...

# %%
l=df.location.unique()
unique_location={}

# %%
for i in range(len(l)):
    unique_location[i]=l[i]

# %%
unique_location
# Out:
# {0: 'Madison, WI 53702',
#  1: 'Madison, WI 53708',
# ...

# %%
df.organization
# Out:
# 0                                                   NaN
# 1                               Printing and Publishing
# 2                       Personal and Household Services
# 3                                      Altec Industries
# 4                                                Retail
#                               ...
# 21995                                               NaN
# 21996    Construction - Residential & Commercial/Office
# 21997                                               NaN
# 21998                         Jernberg Industries, Inc.
# 21999                                               NaN
# Name: organization, Length: 22000, dtype: object

# %%
df.organization.keys()
# Out:
# RangeIndex(start=0, stop=22000, step=1)

# %%
for k in df.organization.keys():
        if df.organization[k] in l:
            temp=df.organization[k]
            df.organization[k]=df.location[k]
            df.location[k]=temp

# %%
for i in df['location']:
    if len(i)>20:
        print(i)
# Out:
# IOPub data rate exceeded.
# The notebook server will temporarily stop sending output
# to the client in order to avoid crashing it.
# To change this limit, set the config variable
# `--NotebookApp.iopub_data_rate_limit`.
#
# Current values:
# NotebookApp.iopub_data_rate_limit=1000000.0 (bytes/sec)
# NotebookApp.rate_limit_window=3.0 (secs)

# %%
df=df[df['location'].apply(lambda x: len(x)<20)]

# %%
df
# Out:
#       date_added                                    job_description  \
# 0            NaN  TeamSoft is seeing an IT Support Specialist to...
# 1            NaN  The Wisconsin State Journal is seeking a flexi...
# 3            NaN  Why Join Altec? If you’re considering a career...
# 4            NaN  Position ID#  76162 # Positions  1 State  CT C...
# 5            NaN  Job Description Job #:  720298Apex Systems has...
# ...          ...                                                ...
# 21993        NaN  We are looking to recruit a personal individua...
# 21995        NaN  This is a major premier Cincinnati based finan...
# 21997        NaN  RE: Adobe AEM-          Client -          Loca...
# 21998        NaN  Jernberg Industries was established in 1937 an...
# 21999        NaN  Contract AdministratorCan you be the point per...
#
#                                                job_title  \
# 0                   IT Support Technician Job in Madison
# ...

# %%
location=df['location'].str.split(',')

# %%
location.str[0]
# Out:
# 0                Madison
# 1                Madison
# 3                  Dixon
# 4               Camphill
# 5        Charlottesville
#               ...
# 21993            Chicago
# 21995         Cincinnati
# 21997            Chicago
# 21998            Chicago
# 21999         Cincinnati
# Name: location, Length: 15624, dtype: object

# %%
location=df['location'].str.split(',')

# %%
location
# Out:
# 0          [Madison,  WI 53702]
# 1          [Madison,  WI 53708]
# 3                  [Dixon,  CA]
# 4               [Camphill,  PA]
# 5        [Charlottesville,  VA]
#                   ...
# 21993      [Chicago,  IL 60603]
# 21995         [Cincinnati,  OH]
# 21997      [Chicago,  IL 60602]
# 21998      [Chicago,  IL 60609]
# 21999         [Cincinnati,  OH]
# Name: location, Length: 15624, dtype: object

# %%
df['location']=location.str[0]
# Out:
# C:\Users\HP\AppData\Local\Temp\ipykernel_13644\385221591.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['location']=location.str[0]

# %%
df['location']
# Out:
# 0                Madison
# 1                Madison
# 3                  Dixon
# 4               Camphill
# 5        Charlottesville
#               ...
# 21993            Chicago
# 21995         Cincinnati
# 21997            Chicago
# 21998            Chicago
# 21999         Cincinnati
# Name: location, Length: 15624, dtype: object

# %%
df['location'].unique().tolist()
# Out:
# ['Madison',
#  'Dixon',
#  'Camphill',
#  'Charlottesville',
#  'Austin',
#  'Chesterfield',
#  'Columbus',
#  'Boston',
#  'Houston',
#  'Wadesboro 28170',
#  'Denver',
#  'Natick',
#  'La Porte 46350',
#  'Chicago',
#  'Knoxville',
#  'Aurora',
#  'Washington',
#  'Oklahoma City',
#  'San Francisco',
#  'Tulsa',
#  'Charleston',
#  'Bradford',
#  'New York',
#  'Skippack',
#  'Fort Wayne',
#  'Dayton',
#  'Livermore',
#  'Ogden',
#  'Ocean',
#  'Stuart',
#  'Fargo',
#  'Tucson',
#  '"Statewide"',
#  'Durham',
#  'Canton',
#  'Plano',
#  'Arlington',
#  'Bethlehem',
#  'Columbus 68601',
#  'Andover',
#  'San Antonio',
#  'Greenville',
#  'Budd Lake',
#  'Bloomington',
#  'Fort Collins',
#  'San Jose',
#  'Lansing',
#  'Galesburg 64101',
#  'Edinburgh 46124',
#  'Tracy',
#  'Dania',
#  'Cleveland',
#  'Tomahawk 54487',
#  'Monroe',
#  'Taylor',
#  'Fort Lauderdale',
#  'Deer Park',
#  'Bafb',
#  'Telecommute',
#  'Nashville',
#  'Hilo 96720',
#  'Los Angeles',
#  'Cambridge 55008',
# ...

# %%
def func(a):
    for i in list(a):
        if i.isnumeric():
            b=list(a).index(i)
            return a[:b]

# %%
df['location']=df['location'].apply(func)
# Out:
# C:\Users\HP\AppData\Local\Temp\ipykernel_13644\3162212414.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['location']=df['location'].apply(func)

# %%
df['location'].unique().tolist()
# Out:
# ['Madison',
#  'Dixon',
#  'Camphill',
#  'Charlottesville',
#  'Austin',
#  'Chesterfield',
#  'Columbus',
#  'Boston',
#  'Houston',
#  'Wadesboro',
#  'Denver',
#  'Natick',
#  'LaPorte',
#  'Chicago',
#  'Knoxville',
#  'Aurora',
#  'Washington',
#  'OklahomaCity',
#  'SanFrancisco',
#  'Tulsa',
#  'Charleston',
#  'Bradford',
#  'NewYork',
#  'Skippack',
#  'FortWayne',
#  'Dayton',
#  'Livermore',
#  'Ogden',
#  'Ocean',
#  'Stuart',
#  'Fargo',
#  'Tucson',
#  'Statewide',
#  'Durham',
#  'Canton',
#  'Plano',
#  'Arlington',
#  'Bethlehem',
#  'Andover',
#  'SanAntonio',
#  'Greenville',
#  'BuddLake',
#  'Bloomington',
#  'FortCollins',
#  'SanJose',
#  'Lansing',
#  'Galesburg',
#  'Edinburgh',
#  'Tracy',
#  'Dania',
#  'Cleveland',
#  'Tomahawk',
#  'Monroe',
#  'Taylor',
#  'FortLauderdale',
#  'DeerPark',
#  'Bafb',
#  'Telecommute',
#  'Nashville',
#  'Hilo',
#  'LosAngeles',
#  'Cambridge',
#  'Racine',
#  'Orlando',
#  'Pasadena',
#  'SantaAna',
#  'Seattle',
# ...

# %%
#pattern = r'[A-Z/a-z]'

# %%
#pattern = r'[0-9]'
#df[df['location'].str.contains(pattern)]['location']
# Out:
# 16          Wadesboro 28170
# 22           La Porte 46350
# 85           Columbus 68601
# 104         Galesburg 64101
# 108         Edinburgh 46124
#                 ...
# 21108        Columbus 43251
# 21250    Philadelphia 19102
# 21327                 60601
# 21603      Cincinnati 45203
# 21727             84 Lumber
# Name: location, Length: 628, dtype: object

# %%
#pattern = r'[A-Z/a-z]'
#df=df[df['location'].str.contains(pattern)]

# %%
df['job_type'].unique().tolist()
# Out:
# ['Full Time Employee',
#  'Full Time',
#  'Part Time Employee',
#  nan,
#  'Full Time, Employee',
#  'Full Time Temporary/Contract/Project',
#  'Full Time , Employee',
#  'Employee',
#  'Part Time',
#  'Full Time, Temporary/Contract/Project',
#  'Part Time, Employee',
#  'Full Time Intern',
#  'Temporary/Contract/Project',
#  'Full Time / Employee',
#  'Full Time , Temporary/Contract/Project',
#  'Per Diem, Employee',
#  'Job Type Full Time Employee',
#  'Per Diem',
#  'Part Time, Temporary/Contract/Project',
#  'Full Time\xa0',
#  'Part Time Intern',
#  'Per Diem Employee',
#  'Part Time/ Temporary/Contract/Project',
#  'Part Time Temporary/Contract/Project',
#  'Part Time , Temporary/Contract/Project',
#  'Full Time\xa0 Employee',
#  'Part Time Seasonal',
#  'Part Time , Employee',
#  'Job Type Employee',
#  'Part Time\xa0',
#  'Full Time / Temporary/Contract/Project',
#  'Part Time, Intern',
#  'Job Type Full Time',
#  'Part Time / Employee',
# ...

# %%
jobtype=df['job_type'].str.split(',')
df['job_type']=jobtype.str[0]
# Out:
# C:\Users\HP\AppData\Local\Temp\ipykernel_13644\1543143472.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['job_type']=jobtype.str[0]

# %%
df['job_type'][df['job_type']=='Full Time Employee']='Full Time'
df['job_type'][df['job_type']=='Part Time Employee']='Part Time'
# Out:
# C:\Users\HP\AppData\Local\Temp\ipykernel_13644\3503087442.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['job_type'][df['job_type']=='Full Time Employee']='Full Time'
# C:\Users\HP\AppData\Local\Temp\ipykernel_13644\3503087442.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['job_type'][df['job_type']=='Part Time Employee']='Part Time'

# %%
df['job_type'].unique().tolist()
# Out:
# ['Full Time',
#  'Part Time',
#  nan,
#  'Full Time Temporary/Contract/Project',
#  'Full Time ',
#  'Employee',
#  'Full Time Intern',
#  'Temporary/Contract/Project',
#  'Full Time / Employee',
#  'Per Diem',
#  'Job Type Full Time Employee',
#  'Full Time\xa0',
#  'Part Time Intern',
#  'Per Diem Employee',
#  'Part Time/ Temporary/Contract/Project',
#  'Part Time Temporary/Contract/Project',
#  'Part Time ',
#  'Full Time\xa0 Employee',
#  'Part Time Seasonal',
#  'Job Type Employee',
#  'Part Time\xa0',
#  'Full Time / Temporary/Contract/Project',
#  'Job Type Full Time',
#  'Part Time / Employee',
#  'Job Type Full Time Temporary/Contract/Project',
#  'Job Type Part Time Employee']

# %%
def j_type(a):
    if 'Full' is in a.split():
        return 'Full time'
    elif 'Part' is in a.split():
        return 'Part time'
    elif 'Per' in a.split():
        return 'Per Diem'
    else:
        np.nan
# Out:
#   File "C:\Users\HP\AppData\Local\Temp\ipykernel_13644\971273409.py", line 2
#     if 'Full' is in a.split():
#                  ^
# SyntaxError: invalid syntax

# %%
df['salary'].unique().tolist()
# Out:
# [nan,
#  '9.00 - 13.00 $ /hour',
#  '80,000.00 - 95,000.00 $ /year',
#  'Excellent Pay and Incentives',
#  '70,000.00 - 100,000.00 $ /year',
#  '75,000.00 - 100,000.00 $ /year',
#  '68,000.00 - 72,000.00 $ /year',
#  '58,000.00 - 65,000.00 $ /year',
#  'Up to $32000.00',
#  '15.00 - 16.00 $ /hour',
#  'Salary, plus commission',
#  '45,000.00 - 100,000.00 $ /yearBonus, Benefits, 401k',
#  '40,000.00 - 50,000.00 $ /yearsalary',
#  '13.75 - 16.75 $ /hourYear End Bonus',
#  'To be discussed.',
#  '40.00 - 50.00 $ /hour',
#  '80,000.00 - 90,000.00 $ /year',
#  '35,000.00 - 45,000.00 $ /year',
#  '80,000.00 - 100,000.00 $ /year',
#  'bonus, 401K matching, medical, vacation',
#  '31,000.00 - 33,000.00 $ /year',
#  '$50,000.00+ /year',
# ...

# %%
if '/hour' in df['salary']:
    df['salary'].split('/hour')[0].replace('$','').strip()
